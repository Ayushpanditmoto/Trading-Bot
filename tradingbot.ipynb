# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/2018.csv')

# %%
df.head()
# Out:
#                   date      open      high       low     close
# 0  2018-01-01 00:00:00  13880.00  13906.37  13841.00  13841.01
# 1  2018-01-01 00:01:00  13841.01  13890.43  13841.01  13890.43
# 2  2018-01-01 00:02:00  13846.64  13890.35  13846.64  13847.51
# 3  2018-01-01 00:03:00  13847.51  13874.92  13823.19  13823.19
# 4  2018-01-01 00:04:00  13823.19  13826.75  13803.20  13803.20

# %%
# Check for missing values
df.isnull().sum()
# Out:
# date     0
# open     0
# high     0
# low      0
# close    0
# dtype: int64

# %%
# Calculate descriptive statistics
df.describe()
# Out:
#                open          high           low         close
# count  10081.000000  10081.000000  10081.000000  10081.000000
# mean   15151.007177  15170.853047  15129.998518  15152.049701
# std     1218.124151   1216.618472   1219.434046   1217.928521
# min    12840.000000  12868.860000  12801.380000  12839.050000
# 25%    13976.130000  14016.820000  13967.440000  13974.660000
# 50%    15013.070000  15035.010000  14991.660000  15013.970000
# 75%    16405.010000  16420.000000  16388.000000  16405.560000
# max    17234.980000  17234.990000  17214.960000  17234.980000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10081 entries, 0 to 10080
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    10081 non-null  object
#  1   open    10081 non-null  float64
#  2   high    10081 non-null  float64
#  3   low     10081 non-null  float64
#  4   close   10081 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 393.9+ KB

# %%
#Convert the date column to datetime format
df['date'] = pd.to_datetime(df['date'])

# %%
# Check for outliers
import seaborn as sns

for column in df.columns:
    sns.boxplot(x=df[column])
    plt.title(column)
    plt.show()

# %%
# Time series plot of closing prices
plt.figure(figsize=(10, 6))
plt.plot(df['date'], df['close'], color='blue')
plt.title('Time Series Plot of Closing Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.grid(True)
plt.show()

# %%
# Distribution of opening, high, low, and closing prices
plt.figure(figsize=(10, 6))
df[['open', 'high', 'low', 'close']].plot(kind='box', vert=False)
plt.title('Box Plot of Opening, High, Low, and Closing Prices')
plt.xlabel('Price')
plt.ylabel('Price Type')
plt.grid(True)
plt.show()

# %%
pip install mplfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.2 MB/s eta 0:00:00
# ...

# %%
# Candlestick plot
from mplfinance.original_flavor import candlestick_ohlc
import matplotlib.pyplot as plt
from matplotlib.dates import date2num

# Convert 'date' column to numerical values compatible with candlestick plot
ohlc_data['date'] = ohlc_data['date'].apply(date2num)

plt.figure(figsize=(10, 6))
ax = plt.subplot()

# Plot candlestick chart
candlestick_ohlc(ax, ohlc_data.values, width=0.6, colorup='green', colordown='red')

# Add titles and labels
plt.title('Candlestick Plot')
plt.xlabel('Date')
plt.ylabel('Price')

# Show plot
plt.show()
